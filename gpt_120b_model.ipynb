# %%
import os
from google import genai
from google.genai import types
from PIL import Image

# 1. Setup Client
client = genai.Client(api_key="AIzaSyB-Vlhb52by9NahGYBLwKkKs5WfDJkcJL8")

# 2. Define the Prompt for Cropping
# This prompt forces the model to return coordinates for the diagram.
PROMPT = """
from the image find the door.
Output only a JSON list containing the bounding box in the following format:
[ymin, xmin, ymax, xmax]
Use normalized coordinates (0 to 1000).
"""

# 3. Send Image to Gemini
img = Image.open(r'C:\Users\bhoge\OneDrive\Documents\Desktop\PDF_Latex_Extraction\pdfs\cetchap1-1-2.pdf')
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=[img, PROMPT],
    config=types.GenerateContentConfig(
        response_mime_type="application/json"
    )
)

import json
coords = json.loads(response.text) 
print(f"Coordinates found: {coords}")
# Out:
# Coordinates found: [[466, 452, 695, 542]]

# %%
# --- Update your execution cell with this code ---

# 1. Inspect the raw coords first to see what Gemini actually sent
print(f"Raw coordinates received: {coords}")

# 2. Extract the actual list of 4 numbers
# Often Gemini returns a list of boxes, so we take the first one: [0]
if isinstance(coords, list) and len(coords) > 0:
    if isinstance(coords[0], list):
        bbox = coords[0]  # If it's [[y, x, y, x]]
    else:
        bbox = coords     # If it's already [y, x, y, x]
else:
    raise ValueError(f"AI returned unexpected format: {coords}")

# 3. Now run the crop with the confirmed 4-value list
cropped_image = get_crop(r'C:\Users\bhoge\OneDrive\Documents\Desktop\PDF_Latex_Extraction\wada.jpeg', bbox)
display(cropped_image)
# Out:
# Raw coordinates received: [[466, 452, 695, 542]]
# <PIL.Image.Image image mode=RGB size=24x34>
